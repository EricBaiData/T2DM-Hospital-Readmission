# %%
import os
from google.cloud import bigquery

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/hakukazuho/.dbt/ericbai_datapractice_mimic_iv.json"
client = bigquery.Client()

# %%
# Define your query
query = """
    SELECT * FROM `mimic-iv-440804.eric_dbt.data_1106`
"""

# Run the query
query_job = client.query(query)

# Fetch the results as a DataFrame
results = query_job.to_dataframe()
results.to_csv('/Users/hakukazuho/t2dm_readmission/ml_models/data/data_1106.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
import pandas as pd

df = pd.read_csv('/Users/hakukazuho/t2dm_readmission/ml_models/data/data_1106.csv')
df.head()
# Out:
#    Unnamed: 0   hadm_id                            race insurance  \
# 0           0  25295337          BLACK/AFRICAN AMERICAN  Medicaid
# 1           1  21575815                           WHITE   Private
# 2           2  27415546  HISPANIC/LATINO - PUERTO RICAN  Medicaid
# 3           3  28259116          BLACK/AFRICAN AMERICAN  Medicare
# 4           4  22916863          BLACK/AFRICAN AMERICAN  Medicaid
#
#                 admission_type  los_hours discharge_location gender  \
# 0                       URGENT         43               HOME      F
# 1               EU OBSERVATION         38                NaN      M
# 2  SURGICAL SAME DAY ADMISSION         61               HOME      F
# 3           DIRECT OBSERVATION         28                NaN      M
# 4                       URGENT         66               HOME      F
#
#    anchor_age  diagnoses_count  labtest_count  medication_count  \
# 0          30                2             10                11
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df.head()
# Out:
#     hadm_id                            race insurance  \
# 0  25295337          BLACK/AFRICAN AMERICAN  Medicaid
# 1  21575815                           WHITE   Private
# 2  27415546  HISPANIC/LATINO - PUERTO RICAN  Medicaid
# 3  28259116          BLACK/AFRICAN AMERICAN  Medicare
# 4  22916863          BLACK/AFRICAN AMERICAN  Medicaid
#
#                 admission_type  los_hours discharge_location gender  \
# 0                       URGENT         43               HOME      F
# 1               EU OBSERVATION         38                NaN      M
# 2  SURGICAL SAME DAY ADMISSION         61               HOME      F
# 3           DIRECT OBSERVATION         28                NaN      M
# 4                       URGENT         66               HOME      F
#
#    anchor_age  diagnoses_count  labtest_count  medication_count  \
# 0          30                2             10                11
# 1          30                5            135                11
# ...
